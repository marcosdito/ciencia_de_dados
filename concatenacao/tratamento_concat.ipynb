# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_concat1.0.csv', sep = ';')
# Out:
# /tmp/ipykernel_2110/3818065626.py:1: DtypeWarning: Columns (1,2,4,5,7,11,14,15,17,18,19,20,21,22,24,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset_concat1.0.csv', sep = ';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411424 entries, 0 to 411423
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   titulo                  410273 non-null  object
#  1   nome_autor              144960 non-null  object
#  2   nome_orientador         144960 non-null  object
#  3   curso                   406552 non-null  object
#  4   nivel                   144960 non-null  object
#  5   tipo_trabalho           126729 non-null  object
#  6   ano                     410273 non-null  float64
#  7   data_defesa             144960 non-null  object
#  8   classificacao           410273 non-null  object
#  9   id_curso                406384 non-null  float64
#  10  id_unidade              411256 non-null  float64
#  11  unidade                 145571 non-null  object
#  12  Unnamed: 0              265313 non-null  float64
#  13  id_projeto_pesquisa     265313 non-null  float64
# ...

# %%
df.dropna(subset=['titulo'], inplace=True)

# %%
df.drop_duplicates(subset=['titulo'], inplace=True)

# %%
df.head()
# Out:
#                                               titulo  \
# 1  explorando o potencial das finanças verdes: um...
# 3  indicadores de desempenho: um estudo da perspe...
# 5  análise e influência do clima organizacional n...
# 7  compras por impulso online em plataformas de m...
# 9  inteligência artificial no futebol: uma revisã...
#
#                          nome_autor                 nome_orientador  \
# 1       ana flavia eufrasio de lima   israel josé dos santos felipe
# 3         alvaro araujo de medeiros            marconi neves macedo
# 5                  eros dias guerra         antonio carlos ferreira
# 7  maria jordiane gomes de oliveira  anatalia saraiva martins ramos
# 9       mike alexandre silva santos  anatalia saraiva martins ramos
#
#            curso      nivel tipo_trabalho     ano              data_defesa  \
# 1  administracao  graduação    monografia  2024.0  2025/11/25 00:00:00.000
# 3  administracao  graduação    monografia  2025.0  2025/09/09 00:00:00.000
# ...

# %%
df['curso'].unique()
df.['curso']

# %%
df.to_csv(
    'dataset_concat2.0.csv',
    sep=';',
     encoding='utf-8',
    index=False
)
