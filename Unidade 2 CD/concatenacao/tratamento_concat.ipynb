# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_concat1.0.csv', sep = ';')
# Out:
# /tmp/ipykernel_883/3818065626.py:1: DtypeWarning: Columns (1,2,4,5,7,12,13,15,16,17,18,19,22,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dataset_concat1.0.csv', sep = ';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304384 entries, 0 to 304383
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   titulo                  303349 non-null  object
#  1   nome_autor              102139 non-null  object
#  2   nome_orientador         102139 non-null  object
#  3   curso                   299514 non-null  object
#  4   nivel                   102139 non-null  object
#  5   tipo_trabalho           83908 non-null   object
#  6   ano                     303349 non-null  float64
#  7   data_defesa             102139 non-null  object
#  8   classificacao           303349 non-null  object
#  9   unidade                 304039 non-null  object
#  10  Unnamed: 0              201210 non-null  float64
#  11  id_projeto_pesquisa     201210 non-null  float64
#  12  codigo_projeto          201210 non-null  object
#  13  palavras_chave          199039 non-null  object
#  14  id_projeto              201210 non-null  float64
#  15  data_inicio             200924 non-null  object
#  16  data_fim                198966 non-null  object
#  17  situacao                201210 non-null  object
#  18  tipo_projeto            201210 non-null  object
#  19  categoria_projeto       201210 non-null  object
#  20  id_unidade              201210 non-null  float64
#  21  id_grupo_pesquisa       163789 non-null  float64
#  22  grupo_pesquisa          163295 non-null  object
#  23  linha_pesquisa          195169 non-null  object
#  24  area_conhecimento_cnpq  197393 non-null  object
# dtypes: float64(6), object(19)
# memory usage: 58.1+ MB

# %%
df.dropna(subset=['titulo'], inplace=True)

# %%
df.drop_duplicates(subset=['titulo'], inplace=True)

# %%
df.head()
# Out:
#                                               titulo  \
# 1  explorando o potencial das finanças verdes: um...
# 3  indicadores de desempenho: um estudo da perspe...
# 5  análise e influência do clima organizacional n...
# 7  compras por impulso online em plataformas de m...
# 9  inteligência artificial no futebol: uma revisã...
#
#                          nome_autor                 nome_orientador  \
# 1       ana flavia eufrasio de lima   israel josé dos santos felipe
# 3         alvaro araujo de medeiros            marconi neves macedo
# 5                  eros dias guerra         antonio carlos ferreira
# 7  maria jordiane gomes de oliveira  anatalia saraiva martins ramos
# 9       mike alexandre silva santos  anatalia saraiva martins ramos
#
#            curso      nivel tipo_trabalho     ano              data_defesa  \
# 1  administracao  graduação    monografia  2024.0  2025/11/25 00:00:00.000
# 3  administracao  graduação    monografia  2025.0  2025/09/09 00:00:00.000
# 5  administracao  graduação    monografia  2025.0  2025/07/24 00:00:00.000
# 7  administracao  graduação    monografia  2025.0  2025/07/24 00:00:00.000
# 9  administracao  graduação    monografia  2025.0  2025/07/24 00:00:00.000
#
#   classificacao                               unidade  ...  data_inicio  \
# 1           tcc  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS  ...          NaN
# 3           tcc  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS  ...          NaN
# 5           tcc  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS  ...          NaN
# 7           tcc  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS  ...          NaN
# 9           tcc  CENTRO DE CIÊNCIAS SOCIAIS APLICADAS  ...          NaN
#
#    data_fim situacao tipo_projeto  categoria_projeto id_unidade  \
# 1       NaN      NaN          NaN                NaN        NaN
# 3       NaN      NaN          NaN                NaN        NaN
# 5       NaN      NaN          NaN                NaN        NaN
# 7       NaN      NaN          NaN                NaN        NaN
# 9       NaN      NaN          NaN                NaN        NaN
#
#   id_grupo_pesquisa grupo_pesquisa linha_pesquisa area_conhecimento_cnpq
# 1               NaN            NaN            NaN                    NaN
# 3               NaN            NaN            NaN                    NaN
# 5               NaN            NaN            NaN                    NaN
# 7               NaN            NaN            NaN                    NaN
# 9               NaN            NaN            NaN                    NaN
#
# [5 rows x 25 columns]

# %%
df.to_csv(
    'dataset_concat2.0.csv',
    sep=';',
     encoding='utf-8',
    index=False
)
